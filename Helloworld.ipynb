# %% [markdown]
# <a href="https://colab.research.google.com/github/braedenbard-source/MIS-2800/blob/main/Helloworld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello world")
# Out:
# Hello world

# %%
print ("MIS is best!")
# Out:
# MIS is best!
